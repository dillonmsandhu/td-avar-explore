# %%
import jax
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

# Add the parent directory to the path so we can import from 'core'
sys.path.append(os.path.abspath('..'))

# Import your specific environment builder
# (Adjust this import if your make_env is located elsewhere)
from core.helpers import make_env

# Setup a dummy config for Breakout
from core.configs import shared_config as config

# Create the Envpool environment wrapped with your JaxEnvPoolWrapper
env = make_env(config)

print(f"Environment initialized: {env.env_name}")
print(f"Number of parallel environments: {env.num_envs}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 13
#       9 sys.path.append(os.path.abspath('..'))
#      11 # Import your specific environment builder
#      12 # (Adjust this import if your make_env is located elsewhere)
# ---> 13 from core.helpers import make_env
#      15 # Setup a dummy config for Breakout
#      16 from core.configs import shared_config as config
#
# File ~/Documents/Research/bayesian-rl/atari/core/helpers.py:1
# ----> 1 import envpool
#       2 from core.wrappers import JaxEnvPoolWrapper
#       3 from core.imports import *
#
# ModuleNotFoundError: No module named 'envpool'
